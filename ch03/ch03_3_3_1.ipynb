# %% [markdown]
# ### 3.3.1 コンテキストとデータセット

# %%
include("../common/util.jl")
# Out:
# create_context_target (generic function with 1 method)

# %%
text = "You say goodbye and I say hello."
corpus, word_to_id, id_to_word = preprocess(text)
# Out:
# ([1 2 … 6 7], Dict{Any,Any}("say" => 2,"goodbye" => 3,"you" => 1,"hello" => 6,"." => 7,"and" => 4,"i" => 5), Dict{Any,Any}(7 => ".",4 => "and",2 => "say",3 => "goodbye",5 => "i",6 => "hello",1 => "you"))

# %%
corpus
# Out:
# 1×8 Adjoint{Int64,Array{Int64,1}}:
#  1  2  3  4  5  2  6  7

# %%
id_to_word
# Out:
# Dict{Any,Any} with 7 entries:
#   7 => "."
#   4 => "and"
#   2 => "say"
#   3 => "goodbye"
#   5 => "i"
#   6 => "hello"
#   1 => "you"

# %%
contexts, target = create_context_target(corpus, window_size=1)
# Out:
# ([1 3; 2 4; … ; 5 6; 2 7], [2 3 … 2 6])

# %%
contexts
# Out:
# 6×2 Array{Int64,2}:
#  1  3
#  2  4
#  3  5
#  4  2
#  5  6
#  2  7

# %%
target
# Out:
# 1×6 Adjoint{Int64,Array{Int64,1}}:
#  2  3  4  5  2  6
