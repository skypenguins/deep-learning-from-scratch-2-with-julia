# %%
# 最適化アルゴリズム定義ファイルの読み込み
@show include("../common/optimizer.jl")
# CommonTrainer構造体定義ファイルの読み込み
@show include("../common/trainer.jl")
# スパイラル・データセット定義ファイルの読み込み
@show include("../dataset/spiral.jl")
# モデル定義ファイルの読み込み
@show include("./two_layer_net.jl")
# Out:
# include("../common/optimizer.jl") = Main.Optimizer
# include("../common/trainer.jl") = iteration!
# include("../dataset/spiral.jl") = Main.Spiral
# include("./two_layer_net.jl") = backward!
# backward! (generic function with 1 method)

# %%
using .Optimizer
using .Spiral

# %%
# ハイパーパラメータの設定
max_epoch = 300
batch_size = 10
hidden_size = 30
learning_rate = 1.0
# Out:
# 1.0

# %%
x, t = load_data()
model = TwoLayerNet(input_size=2, hidden_size=hidden_size, output_size=3)
optimizer = SGD(lr=learning_rate)
# Out:
# seed = 1984
# SGD(1.0)

# %%
trainer = Trainer(model, optimizer)
fit!(trainer, x, t, max_epoch=max_epoch, batch_size=batch_size, eval_interval=10)
# Out:
# | epoch 0 | iter 10 / 30 | loss 14.1
# | epoch 0 | iter 20 / 30 | loss 13.48
# | epoch 0 | iter 30 / 30 | loss 12.06
# | epoch 1 | iter 10 / 30 | loss 12.32
# | epoch 1 | iter 20 / 30 | loss 12.7
# | epoch 1 | iter 30 / 30 | loss 11.93
# | epoch 2 | iter 10 / 30 | loss 10.48
# | epoch 2 | iter 20 / 30 | loss 9.47
# | epoch 2 | iter 30 / 30 | loss 9.3
# | epoch 3 | iter 10 / 30 | loss 11.16
# | epoch 3 | iter 20 / 30 | loss 10.53
# | epoch 3 | iter 30 / 30 | loss 9.87
# | epoch 4 | iter 10 / 30 | loss 8.35
# | epoch 4 | iter 20 / 30 | loss 7.43
# | epoch 4 | iter 30 / 30 | loss 7.12
# | epoch 5 | iter 10 / 30 | loss 8.63
# | epoch 5 | iter 20 / 30 | loss 7.65
# | epoch 5 | iter 30 / 30 | loss 6.96
# | epoch 6 | iter 10 / 30 | loss 9.46
# | epoch 6 | iter 20 / 30 | loss 8.19
# | epoch 6 | iter 30 / 30 | loss 7.72
# | epoch 7 | iter 10 / 30 | loss 8.65
# | epoch 7 | iter 20 / 30 | loss 8.22
# | epoch 7 | iter 30 / 30 | loss 7.89
# | epoch 8 | iter 10 / 30 | loss 7.12
# ...

# %%
using Plots
gr()

plot(trainer.loss_list)
